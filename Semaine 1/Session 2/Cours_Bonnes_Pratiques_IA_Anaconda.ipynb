# %% [markdown]
# # Bonnes pratiques de programmation & projets IA
# ## Environnement Conda + Jupyter Notebook
#
# Ce notebook est un **support de cours + TP complet**.
# Il doit être utilisé avec **Anaconda**.

# %% [markdown]
# ## Objectifs
#
# À la fin de ce notebook, vous saurez :
# - Créer un environnement Conda propre
# - L'afficher comme kernel Jupyter
# - Installer les packages avec `requirements.txt`
# - Structurer un projet IA professionnel (data / modèle)
# - Gérer les clés API avec `.env`
# - Appliquer les bonnes pratiques valables pour TOUS vos projets futurs

# %% [markdown]
# ## 1. Création de l’environnement Conda (à faire dans le terminal)
#
# ```bash
# conda create -n ia_project python=3.11 -y
# conda activate ia_project
# conda install -y jupyter ipykernel
# python -m ipykernel install --user --name ia_project --display-name "Python (ia_project)"
# jupyter notebook
# ```
#
# Puis sélectionnez le kernel **Python (ia_project)**.

# %%
import sys
sys.executable

# %% [markdown]
# ## 2. Installation des packages avec requirements.txt
#
# Une fois l'environnement Conda créé et activé, installez les dépendances du projet à partir d'un fichier `requirements.txt`.
#
# ### Création du fichier requirements.txt
#
# Créez un fichier `requirements.txt` à la racine de votre projet avec tous les packages nécessaires :
#
# ```txt
# # Packages nécessaires pour le projet
# pdfplumber>=0.10.0
# openai>=1.0.0
# python-dotenv>=1.0.0
# ipython>=8.0.0
# jupyter>=1.0.0
# ```
#
# ### Installation dans l'environnement virtuel
#
# Dans le terminal, avec l'environnement Conda activé :
#
# ```bash
# # S'assurer que l'environnement est activé
# conda activate ia_project
#
# # Installer tous les packages depuis requirements.txt
# pip install -r requirements.txt
# ```
#
# ### Avantages de requirements.txt
#
# - ✅ **Reproductibilité** : Tous les collaborateurs utilisent les mêmes versions
# - ✅ **Simplicité** : Une seule commande pour installer toutes les dépendances
# - ✅ **Versioning** : Le fichier peut être versionné dans Git
# - ✅ **Documentation** : Liste claire des dépendances du projet
#
# ### Mise à jour de requirements.txt
#
# Pour générer automatiquement un `requirements.txt` à partir de votre environnement actuel :
#
# ```bash
# pip freeze > requirements.txt
# ```
#
# 👉 **Bonnes pratiques** :
# - Spécifiez les versions exactes pour la production (`==`)
# - Utilisez des versions minimales (`>=`) pour le développement
# - Mettez à jour `requirements.txt` à chaque ajout de package

# %% [markdown]
# ## 2. Structure professionnelle d’un projet IA
#
# ```
# ia_project/
# ├─ notebooks/
# ├─ data/
# │  ├─ raw/
# │  ├─ interim/
# │  └─ processed/
# ├─ models/
# │  ├─ artifacts/
# │  └─ metrics/
# ├─ src/
# │  ├─ config.py
# │  ├─ data/
# │  ├─ features/
# │  ├─ modeling/
# │  ├─ services/
# │  └─ utils/
# ├─ .env
# ├─ .env.example
# ├─ environment.yml
# └─ README.md
# ```
#
# Règles :
# - `raw` est intouchable
# - la logique ne vit pas dans les notebooks
# - le code réutilisable est dans `src/`

# %% [markdown]
# ## 4. Gestion sécurisée des clés API
#
# ### `.env`
# ```env
# OPENAI_API_KEY=sk-xxxx
# ```
#
# ### `.env.example`
# ```env
# OPENAI_API_KEY=your_api_key_here
# ```
#
# 👉 `.env` ne doit **JAMAIS** être versionné.

# %% [markdown]
# ## 5. Configuration centralisée (`config.py`)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if not OPENAI_API_KEY:
    raise RuntimeError("Clé API manquante")

# %% [markdown]
# ## 6. Bonnes pratiques à appliquer pour la suite
#
# - 1 projet = 1 environnement
# - pas de secrets dans le code
# - notebooks = exploration uniquement
# - fonctions courtes, lisibles
# - structure avant performance
# - environnement toujours reproductible
#
# > Vous serez jugés sur la qualité de votre projet, pas sur votre modèle.
