# %% [markdown]
# # Analyse de Document Financier avec Intelligence Artificielle
# ## Analyse du Rapport Q1 2023 de Tesla
#
# Ce notebook utilise l'IA pour analyser et extraire les informations clés d'un document financier.

# %% [markdown]
# ## Configuration et Importation des Bibliothèques

# %%
# !pip install pdfplumber

# %%
# Bibliothèques pour le traitement de PDF
import pdfplumber
from IPython.display import HTML, display

# Bibliothèques pour l'API OpenAI
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
# Initialisation du client OpenAI avec la clé API
api_key = "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"

# %% [markdown]
# ## Extraction du Contenu du Document PDF

# %%
# Chemin vers le document PDF à analyser
document_path = "document/TSLA-Q1-2023-Update.pdf"

# %%
# Extraction du texte depuis le PDF avec pdfplumber
document_text = ""
total_pages = 0

with pdfplumber.open(document_path) as pdf:
    total_pages = len(pdf.pages)
    print(f"Nombre de pages dans le document : {total_pages}")
    
    # Extraction du texte de chaque page
    for i, page in enumerate(pdf.pages, 1):
        page_text = page.extract_text()
        if page_text:
            document_text += f"\n--- Page {i} ---\n{page_text}\n"
        print(f"Page {i} traitée...")

print(f"\nExtraction terminée. Longueur totale du texte : {len(document_text)} caractères")
# Out:
# Nombre de pages dans le document : 29
# Page 1 traitée...
# Page 2 traitée...
# Page 3 traitée...
# Page 4 traitée...
# Page 5 traitée...
# Page 6 traitée...
# Page 7 traitée...
# Page 8 traitée...
# Page 9 traitée...
# Page 10 traitée...
# Page 11 traitée...
# Page 12 traitée...
# Page 13 traitée...
# Page 14 traitée...
# Page 15 traitée...
# Page 16 traitée...
# Page 17 traitée...
# Page 18 traitée...
# Page 19 traitée...
# Page 20 traitée...
# Page 21 traitée...
# Page 22 traitée...
# Page 23 traitée...
# Page 24 traitée...
# Page 25 traitée...
# Page 26 traitée...
# Page 27 traitée...
# Page 28 traitée...
# Page 29 traitée...
#
# Extraction terminée. Longueur totale du texte : 34283 caractères

# %%
# Aperçu du texte extrait (premiers 1000 caractères)
print("Aperçu du contenu extrait :")
print("=" * 80)
print(document_text[:1000])
print("=" * 80)
# Out:
# Aperçu du contenu extrait :
# ...
#
# --- Page 1 ---
# Q1 2023 Update
# 1
#
# --- Page 2 ---
# Highlights 03
# Financial Summary 04
# Operational Summary 06
# Vehicle Capacity 07
# Core Technology 08
# Other Highlights 09
# Outlook 10
# Photos & Charts 11
# Key Metrics 19
# Financial Statements 22
# Additional Information 28
#
# --- Page 3 ---
# H I G H L I G H T S S U M M A R Y
# Profitability 11.4% operating margin in Q1 In the current macroeconomic environment, we see this year as a unique
# opportunity for Tesla. As many carmakers are working through challenges with the
# $2.7B GAAP operating income in Q1 unit economics of their EV programs, we aim to leverage our position as a cost
# leader. We are focused on rapidly growing production, investments in autonomy
# $2.5B GAAP net income in Q1 and vehicle software, and remaining on track with our growth investments.
# $2.9B non-GAAP net income1 in Q1 Our near-term pricing strategy considers a long-term view on per vehicle
# ...

# %% [markdown]
# ## Définition du Prompt d'Analyse
#
# Le prompt suivant guide l'IA pour analyser le document financier de manière structurée.

# %%
# Prompt personnalisé pour l'analyse de documents financiers
analyse_prompt = """Tu es un analyste financier expert spécialisé dans l'analyse de rapports trimestriels d'entreprises technologiques.

Ta mission est d'analyser le document fourni et de produire une analyse complète et structurée selon le format suivant :

## 📊 Informations Générales
- **Entreprise** : Nom de l'entreprise
- **Période** : Trimestre et année analysés
- **Date de publication** : Date du rapport

## 💼 Résumé Exécutif
Un résumé concis (200-400 mots) des points les plus importants du rapport, incluant :
- Les résultats financiers principaux
- Les développements stratégiques majeurs
- Les défis et opportunités identifiés

## 📈 Indicateurs Clés de Performance
Liste les métriques financières et opérationnelles les plus significatives avec leurs valeurs :
- Chiffre d'affaires / Revenus
- Bénéfices / Pertes
- Autres métriques pertinentes (livraisons, production, etc.)

## 🎯 Points Marquants
Les 5-7 points les plus importants à retenir du rapport, présentés sous forme de puces.

## 🔍 Analyse Stratégique
Une analyse des décisions stratégiques, investissements, ou changements de direction mentionnés dans le document.

## ⚠️ Risques et Défis
Les principaux risques, défis ou préoccupations mentionnés dans le document.

## 🚀 Perspectives Futures
Les informations fournies concernant les perspectives, prévisions ou orientations futures de l'entreprise.

## 📚 Terminologie Importante
Définitions des termes techniques ou financiers spécifiques utilisés dans le document (3-5 termes maximum).

### Instructions de Style
- Utilise un ton professionnel mais accessible
- Sois précis avec les chiffres et données
- Structure clairement l'information
- Mets en évidence les informations les plus critiques
"""

# %% [markdown]
# ## Génération de l'Analyse avec GPT-5
#
# Utilisation de l'API OpenAI pour générer l'analyse complète du document.

# %%
# Si besoin : pip install -U openai

import os
from openai import OpenAI

# Option 1 : la variable d'env OPENAI_API_KEY est déjà définie (recommandé)
openai_client = OpenAI(api_key=api_key)

# Option 2 : sinon, tu peux la passer explicitement (moins recommandé)
# openai_client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# %%
# %%time
# Appel à l'API OpenAI pour générer l'analyse

reponse_api = openai_client.responses.create(
    model="gpt-5",
    instructions=analyse_prompt,
    input=document_text
)
    
# Extraction du texte de la réponse
analyse_complete = reponse_api.output_text

print("✅ Analyse générée avec succès!")
print("\n" + "="*80)
print(analyse_complete)
print("="*80)
# Out:
# ✅ Analyse générée avec succès!
#
# ...
# ## 📊 Informations Générales
# - Entreprise : Tesla, Inc.
# - Période : T1 2023
# - Date de publication : 19 avril 2023 (webcast des résultats)
#
# ## 💼 Résumé Exécutif
# ...

# %% [markdown]
# ## Affichage Formaté de l'Analyse
#
# Affichage de l'analyse finale avec formatage Markdown pour une meilleure lisibilité.

# %%
# Affichage de l'analyse avec formatage Markdown

from IPython.display import Markdown
display(Markdown(analyse_complete))
# Out:
# ## 📊 Informations Générales
# - Entreprise : Tesla, Inc.
# - Période : T1 2023
# - Date de publication : 19 avril 2023 (webcast des résultats)
#
# ## 💼 Résumé Exécutif
# Tesla a livré un T1 2023 solide en volume et en diversification de revenus, mais avec une pression notable sur les marges liée aux baisses de prix et à l’environnement macro. Le chiffre d’affaires progresse de 24% en glissement annuel à 23,33 Md$, porté par la hausse des livraisons automobiles (+36% à 422 875 unités) et l’accélération des activités “Energy” (+148% de revenus) et “Services & Autres” (+44%). Toutefois, l’ASP en baisse, un FX défavorable (~0,8 Md$) et des coûts plus élevés (matières premières, logistique, garanties), combinés aux coûts de montée en cadence des usines récentes et des cellules 4680, compriment la rentabilité: marge brute totale à 19,3% (-977 pb) et marge opérationnelle à 11,4% (-779 pb). Le résultat opérationnel atteint 2,66 Md$, le résultat net GAAP 2,51 Md$ (non-GAAP 2,93 Md$).
#
# ...

# %%
# %%time
# Appel à l'API OpenAI pour générer l'analyse
analyse_prompt= "Quel est le chiffres d'affaires de l'entreprise? Peux-tu rajouter la source la page du document"
reponse_api = openai_client.responses.create(
    model="gpt-5",
    instructions=analyse_prompt,
    input=document_text
)
    
# Extraction du texte de la réponse
analyse_complete = reponse_api.output_text

print("✅ Analyse générée avec succès!")
print("\n" + "="*80)
print(analyse_complete)
print("="*80)
# Out:
# ✅ Analyse générée avec succès!
#
# ...
# Le chiffre d’affaires total (Total revenues) de Tesla au T1 2023 est de 23,329 M$ (soit 23,3 Md$).
#
# Source:
# - Page 4 — Financial Summary: “Total revenues … Q1-2023: 23,329”
# - Page 23 — Statement of Operations: “Total revenues … 23,329”
# ...
# CPU times: user 8.84 ms, sys: 4.28 ms, total: 13.1 ms
# Wall time: 30.2 s

# %% [markdown]
# ## Sauvegarde de l'Analyse (Optionnel)
#
# Vous pouvez sauvegarder l'analyse dans un fichier texte pour référence future.

# %%
# Sauvegarde optionnelle de l'analyse dans un fichier
if analyse_complete:
    fichier_sortie = "tesla_q1_2023_analyse.txt"
    with open(fichier_sortie, "w", encoding="utf-8") as f:
        f.write("ANALYSE DU RAPPORT TESLA Q1 2023\n")
        f.write("="*80 + "\n\n")
        f.write(analyse_complete)
    print(f"✅ Analyse sauvegardée dans : {fichier_sortie}")
else:
    print("⚠️ Aucune analyse à sauvegarder.")
# Out:
# ✅ Analyse sauvegardée dans : tesla_q1_2023_analyse.txt
